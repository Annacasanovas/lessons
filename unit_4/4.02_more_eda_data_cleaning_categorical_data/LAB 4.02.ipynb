# %% [markdown]
# ### Instructions
#
# 1. Import the necessary libraries if you are starting a new notebook.
# 2. Load the csv. Use the variable `customer_df` as `customer_df = pd.read_csv()`.
# 3. What should we do with the `customer_id` column?
# 4. Load the continuous and discrete variables into `numericals_df` and `categorical_df` variables, for eg.:
#     ```py
#     numerical_df = customer_df.select_dtypes()
#     categorical_df = customer_df.select_dtypes()
#     ```
# 5. Plot every categorical variable. What can you see in the plots? Note that in the previous lab you used a bar plot to plot categorical data, with each unique category in the column on the x-axis and an appropriate measure on the y-axis. However, this time you will try a different plot. This time in each plot for the categorical variable you will have, each unique category in the column on the x-axis and the target(which is numerical) on the Y-axis
# 6. For the categorical data, check if there is any data cleaning that need to perform.
# **Hint**: You can use the function `value_counts()` on each of the categorical columns and check the representation of different categories in each column. Discuss if this information might in some way be used for data cleaning.

# %% [markdown]
# 1. Import the necessary libraries if you are starting a new notebook.

# %%
# Base libraries
import pandas as pd
import numpy as np
  
pd.set_option('display.max_columns', None)
  
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
  
# %matplotlib inline

# %% [markdown]
# 2. Load the csv. Use the variable `customer_df` as `customer_df = pd.read_csv()`
#
# 3. What should we do with the `customer_id` column?
#     We should delete it as it is only a unique identifier for each row in the data. You can relate this to the primary key in a table in SQL
#
# 4. Load the continuous and discrete variables into `numericals_df` and `categorical_df` variables, for eg.

# %%
customer_df = pd.read_csv('./files_for_lesson_and_activities/unit4.csv')

# %%
customer_df
# Out:
#        Unnamed: 0 STATE PVASTATE   DOB MDMAUD RECP3 GENDER DOMAIN  INCOME  \
# 0               0    IL      NaN  3712   XXXX   NaN      F     T2     NaN
# 1               1    CA      NaN  5202   XXXX   NaN      M     S1     6.0
# 2               2    NC      NaN     0   XXXX   NaN      M     R2     3.0
# 3               3    CA      NaN  2801   XXXX   NaN      F     R2     1.0
# 4               4    FL      NaN  2001   XXXX     X      F     S2     3.0
# ...           ...   ...      ...   ...    ...   ...    ...    ...     ...
# 90564       90564    FL      NaN  4803   XXXX   NaN      F     S2     6.0
# 90565       90565    AK      NaN     0   XXXX   NaN      M     C2     NaN
# 90566       90566    TX      NaN  5001   XXXX   NaN      M     C1     7.0
# 90567       90567    MI      NaN  3801   XXXX     X      M     C3     NaN
# 90568       90568    NC      NaN  1801   C1CM   NaN      F     C1     5.0
#
#       HOMEOWNR   HV1   HV2  HV3  HV4   IC1   IC2   IC3   IC4    IC5 VETERANS  \
# 0          NaN   479   635    3    2   307   318   349   378  12883      NaN
# 1            H  5468  5218   12   10  1088  1096  1026  1037  36175      NaN
# 2            U   497   546    2    1   251   292   292   340  11576      NaN
# 3            U  1000  1263    2    1   386   388   396   423  15130      NaN
# 4            H   576   594    4    3   240   250   293   321   9836      NaN
# ...        ...   ...   ...  ...  ...   ...   ...   ...   ...    ...      ...
# 90564        H   733   875    4    3   285   288   333   334  11390      NaN
# 90565      NaN   988  1025    6    6   433   481   499   535  18807      NaN
# 90566        H  1679  1723    3    3   806   836   802   849  26538      NaN
# 90567      NaN   376   377    4    3   263   264   319   345  12178      NaN
# 90568        U   938  1049    5    5   451   474   499   519  16699      NaN
#
#        NUMPROM  CARDPROM  CARDPM12  NUMPRM12  MAXADATE RFA_2  NGIFTALL  \
# 0           74        27         6        14      9702   L4E        31
# 1           32        12         6        13      9702   L2G         3
# 2           63        26         6        14      9702   L4E        27
# 3           66        27         6        14      9702   L4E        16
# 4          113        43        10        25      9702   L2F        37
# ...        ...       ...       ...       ...       ...   ...       ...
# 90564       59        23         5        12      9702   L4D        24
# 90565       14         6         5        12      9702   L1G         1
# 90566       10         4         3         8      9702   L1F         1
# 90567       33        14         7        17      9702   L3E         7
# 90568      139        32         6        35      9702   L1G        39
#
#        TIMELAG    AVGGIFT
# 0          4.0   7.741935
# 1         18.0  15.666667
# 2         12.0   7.481481
# 3          9.0   6.812500
# 4         14.0   6.864865
# ...        ...        ...
# 90564      3.0   3.375000
# 90565      NaN  25.000000
# 90566      NaN  20.000000
# 90567      3.0   8.285714
# 90568      6.0  96.794872
#
# [90569 rows x 29 columns]

# %%
numerical_df = customer_df.select_dtypes()
categorical_df = customer_df.select_dtypes()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 numerical_df = customer_df.select_dtypes()
#       2 categorical_df = customer_df.select_dtypes()
#
# File ~\Anaconda3\lib\site-packages\pandas\core\frame.py:4333, in DataFrame.select_dtypes(self, include, exclude)
#    4330 selection = (frozenset(include), frozenset(exclude))
#    4332 if not any(selection):
# -> 4333     raise ValueError("at least one of include or exclude must be nonempty")
#    4335 # convert the myriad valid dtypes object to a single representation
#    4336 def check_int_infer_dtype(dtypes):
#
# ValueError: at least one of include or exclude must be nonempty

# %%
numerical_df = customer_df.select_dtypes(np.number)
categorical_df = customer_df.select_dtypes(np.object)
# Out:
# C:\Users\JA993RS\AppData\Local\Temp\ipykernel_10336\3412960944.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categorical_df = customer_df.select_dtypes(np.object)

# %%
for col in categorical_df.columns:
      sns.barplot(x = col, y = 'DOB', data = customer_df)
      plt.show()

# %%
for col in categorical_df.columns:
      print(categorical_df[col].value_counts())
# Out:
# CA    16284
# FL     7959
# TX     7166
# IL     6124
# MI     5375
# NC     3956
# WA     3383
# GA     3261
# IN     2855
# WI     2656
# MO     2583
# TN     2396
# AZ     2278
# MN     2081
# OR     2045
# CO     1929
# SC     1660
# AL     1627
# OK     1553
# KY     1542
# LA     1533
# KS     1233
# IA     1214
# AR      969
# MS      948
# NV      923
# NM      824
# NE      715
# UT      546
# ID      504
# MT      498
# HI      423
# SD      278
# AK      275
# WY      267
# ND      241
# AP       78
# NY       70
# VA       54
# OH       52
# PA       36
# MD       30
# MA       25
# NJ       24
# CT       20
# AA       15
# AE       14
# ME       11
# NH        8
# RI        6
# VT        6
# VI        5
# WV        3
# GU        3
# DE        3
# AS        1
# DC        1
# Name: STATE, dtype: int64
# P    1380
# E       5
# Name: PVASTATE, dtype: int64
# XXXX    90290
# C1CM       59
# L1CM       44
# I1CM       34
# D2CM       27
# C2CM       23
# D1CM       19
# L2CM       14
# C1LM        8
# L1LM        8
# I2CM        7
# D5CM        5
# D5MM        5
# D2MM        4
# I1LM        3
# D5TM        3
# C2MM        3
# C5CM        3
# C2LM        2
# C1MM        1
# I2MM        1
# I5CM        1
# I5MM        1
# C5MM        1
# L1MM        1
# C5TM        1
# L2TM        1
# Name: MDMAUD, dtype: int64
# X    1833
# Name: RECP3, dtype: int64
# F    48668
# M    37132
# U     1635
# J      336
# C        2
# A        1
# Name: GENDER, dtype: int64
# R2    13006
# T2    11717
# S1    10866
# S2     8054
# C2     7834
# C1     5793
# C3     5056
# T1     4712
# R3     4572
# U1     4259
# U2     3111
# U3     2484
# T3     2092
# S3     1817
# U4     1735
# R1     1285
# Name: DOMAIN, dtype: int64
# H    49646
# U    19872
# Name: HOMEOWNR, dtype: int64
# Y    9846
# Name: VETERANS, dtype: int64
# L1F    29207
# L1G    12007
# L2F    10398
# L3E     7244
# L2E     4681
# L1E     4667
# L4D     4449
# L2G     4410
# L4E     3647
# L3F     3352
# L3D     2267
# L4F     1951
# L3G     1425
# L4G      864
# Name: RFA_2, dtype: int64
